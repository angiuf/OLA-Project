# %%
from Source.Auxiliary import *
from Source.Save_Load import *

# %%
ucb_1 = load_object("./data/ucb_data_test_1")
ucb_2 = load_object("./data/ucb_data_test_2")
ucb_3 = load_object("./data/ucb_data_test_3")
ts_1 = load_object("./data/ts_data_test_1")
ts_2 = load_object("./data/ts_data_test_2")
ts_3 = load_object("./data/ts_data_test_3")

# %%
show_results(ucb_1.param[0], "UCB test, first case mean cumulative regret")
show_reward(ucb_1.param[1], "UCB test, first case mean reward")

# %%
show_results(ucb_2.param[0], "UCB test, second case mean cumulative regret")
show_reward(ucb_2.param[1], "UCB test, second case mean reward")

# %%
show_results(ucb_3.param[0], "UCB test, third case mean cumulative regret")
show_reward(ucb_3.param[1], "UCB test, third case mean reward")

# %%
show_results(ts_1.param[0], "TS test, first case mean cumulative regret")
show_reward(ts_1.param[1], "TS test, first case mean reward")

# %%
show_results(ts_2.param[0], "TS test, second case mean cumulative regret")
show_reward(ts_2.param[1], "TS test, second case mean reward")

# %%
show_results(ts_3.param[0], "TS test, third case mean cumulative regret")
show_reward(ts_3.param[1], "TS test, third case mean reward")
